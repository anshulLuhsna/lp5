# %% [markdown]
# **Stock — blank run**
#
# A column of prices in, the next step out. Respect time order, scale on the past only, carve sliding windows, reshape for the recurrent stack, train, replay the same windowing on the tail, inverse-scale predictions, overlay the lines.

# %%
# Imports

# %%
# Load dataset

# %%
# Split & scale

# %%
# Windows for training

# %%
# Reshape for LSTM

# %%
# Model & compile

# %%
# Train

# %%
# Test windows & predict

# %%
# Plot

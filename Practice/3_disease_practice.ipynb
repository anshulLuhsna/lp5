# %% [markdown]
# **Plant disease — blank run**
#
# Folders of leaves in, a label out. Point the generators at train/valid/test, stack conv blocks until the map is small enough, dense head, train with a validation stream, save if you care, then predictions and curves.

# %%
# Imports

# %%
# Paths

# %%
# Generators

# %%
# Data from directories

# %%
# CNN

# %%
# Compile

# %%
# Train

# %%
# Save (optional)

# %%
# Metrics

# %%
# Predict

# %%
# Plot

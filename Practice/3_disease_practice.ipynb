# %% [markdown]
# # Plant Disease CNN — Practice Template
#
# **Task:** Classify plant leaf images into 38 disease/healthy categories (multi-class).
#
# **Flow to memorise:**
# 1. Imports
# 2. Define train/valid/test paths
# 3. ImageDataGenerator — augment train, only rescale valid/test
# 4. flow_from_directory for all three splits
# 5. Build CNN: [Conv2D(32)→Pool→Drop] → [Conv2D(64)→Pool→Drop] → [Conv2D(128)→Pool→Drop] → Flatten → Dense(128) → Drop(0.5) → Dense(num_classes, softmax)
# 6. Compile: adam / categorical_crossentropy / accuracy + model.summary()
# 7. Fit with validation_data=valid_data
# 8. Save model as .keras
# 9. Print final accuracy
# 10. Predict → argmax → class name
# 11. Plot accuracy + loss curves

# %%
# ── Step 1: Imports ───────────────────────────────────────────────────────────
# TODO: import numpy, matplotlib
# TODO: import Sequential
# TODO: import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
# TODO: import ImageDataGenerator

# %%
# ── Step 2: Dataset Paths ─────────────────────────────────────────────────────
# TODO: set train_path, valid_path, test_path

# %%
# ── Step 3: Image Data Generators ────────────────────────────────────────────
# TODO: train_datagen with rescale=1/255, rotation_range=20, zoom_range=0.2, horizontal_flip=True
# TODO: valid_datagen and test_datagen with only rescale=1/255

# %%
# ── Step 4: Load Images from Folders ─────────────────────────────────────────
# TODO: flow_from_directory for train (target_size=128x128, batch=32, class_mode='categorical')
# TODO: flow_from_directory for valid (same settings)
# TODO: flow_from_directory for test  (batch=16, class_mode=None, shuffle=False)

# %%
# ── Step 5: Build CNN ─────────────────────────────────────────────────────────
# TODO: Block 1 — Conv2D(32,(3,3),relu, input_shape=(128,128,3)) → MaxPool → Dropout(0.25)
# TODO: Block 2 — Conv2D(64,(3,3),relu) → MaxPool → Dropout(0.25)
# TODO: Block 3 — Conv2D(128,(3,3),relu) → MaxPool → Dropout(0.25)
# TODO: Flatten()
# TODO: Dense(128, relu) → Dropout(0.5)
# TODO: Dense(train_data.num_classes, softmax)  ← softmax for multi-class!

# %%
# ── Step 6: Compile ───────────────────────────────────────────────────────────
# TODO: compile(adam, categorical_crossentropy, accuracy)
# TODO: model.summary()

# %%
# ── Step 7: Train ─────────────────────────────────────────────────────────────
# TODO: model.fit(train_data, validation_data=valid_data, epochs=10)

# %%
# ── Step 8: Save Model ────────────────────────────────────────────────────────
# TODO: model.save('plant_disease_cnn_model.keras')

# %%
# ── Step 9: Print Final Accuracy ──────────────────────────────────────────────
# TODO: print history.history['accuracy'][-1]
# TODO: print history.history['val_accuracy'][-1]

# %%
# ── Step 10: Predict Class Names ─────────────────────────────────────────────
# TODO: predictions = model.predict(test_data)
# TODO: predicted_classes = np.argmax(predictions, axis=1)
# TODO: class_labels = list(train_data.class_indices.keys())
# TODO: loop and print class_labels[cls] for each image

# %%
# ── Step 11: Plot Accuracy & Loss ─────────────────────────────────────────────
# TODO: plot training vs validation accuracy
# TODO: plot training vs validation loss
